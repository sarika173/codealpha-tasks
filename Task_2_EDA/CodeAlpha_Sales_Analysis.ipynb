# %%
import pandas as pd
df = pd.read_csv("/sales_data.csv")
df
# Out:
#          Date  Product Region  Sales
# 0  2024-01-01  Shampoo   East   1200
# 1  2024-01-02      Oil   West    900
# 2  2024-01-03     Soap  North    500
# 3  2024-01-04  Shampoo  South   1500
# 4  2024-01-05      Oil   East    700
# 5  2024-01-06     Soap   West    400
# 6  2024-01-07  Shampoo  North   1300

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     7 non-null      object
#  1   Product  7 non-null      object
#  2   Region   7 non-null      object
#  3   Sales    7 non-null      int64
# dtypes: int64(1), object(3)
# memory usage: 356.0+ bytes

# %%
product_sales = df.groupby("Product")["Sales"].sum()
product_sales
# Out:
# Product
# Oil        1600
# Shampoo    4000
# Soap        900
# Name: Sales, dtype: int64

# %%
import matplotlib.pyplot as plt

product_sales.plot(kind='bar')
plt.title("Product Wise Sales")
plt.xlabel("Product")
plt.ylabel("Total Sales")

plt.savefig("Product_Wise_Sales.png")
plt.show()

# %%
df['Sales'].sum()
# Out:
# np.int64(6500)

# %%
df['Sales'].min()
# Out:
# 400

# %%
df['Sales'].mean()
# Out:
# np.float64(928.5714285714286)

# %%
df.describe()
# Out:
#              Sales
# count     7.000000
# mean    928.571429
# std     419.182879
# min     400.000000
# 25%     600.000000
# 50%     900.000000
# 75%    1250.000000
# max    1500.000000
